# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pip install seaborn

# %% [markdown]
# ## Fe I

# %%
wave_peak = np.array([5133.69,5150.84,5151.91,5159.06,5162.27,5194.94,5198.71,5232.94,5242.49,5250.21,5281.79,5302.31,5307.36,5322.04,5339.93,5341.02,5364.87,5367.47,5369.96,5373.71,5393.17,5400.50,5410.91,5445.04,5487.75,5506.78,5522.45,5554.90,5560.21,5563.60,5567.39,5569.62,5572.84,5576.09,5624.02,5686.53,5691.50,5717.83,5731.76,5762.99,5791.02,5883.82,5916.25,6024.06,6027.05,6056.01,6065.48,6079.01,6136.61,6137.69,6151.62,6157.73,6170.51,6173.34,6191.56,6200.31,6213.43,6230.72,6252.56,6265.13,6322.69,6393.60,6411.65,6419.95,6421.35,6430.85,6592.91,6593.87,6609.11,6750.15])
W_lon = np.array([89,114,106,30,82,123,87,139,58,85,101,90,84,43,95,135,71,75,82,22,91,59,71,62,43,130,14,41,15,46,38,95,104,76,12,26,10,25,22,58,36,34,37,53,29,25,106,25,115,107,31,36,28,59,114,51,74,121,107,85,59,120,82,41,100,108,93,68,49,69])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([513.369, 515.084, 515.191, 515.906, 516.227, 519.494, 519.871,
#         523.294, 524.249, 525.021, 528.179, 530.231, 530.736, 532.204,
#         533.993, 534.102, 536.487, 536.747, 536.996, 537.371, 539.317,
#         540.05 , 541.091, 544.504, 548.775, 550.678, 552.245, 555.49 ,
#         556.021, 556.36 , 556.739, 556.962, 557.284, 557.609, 562.402,
#         568.653, 569.15 , 571.783, 573.176, 576.299, 579.102, 588.382,
#         591.625, 602.406, 602.705, 605.601, 606.548, 607.901, 613.661,
#         613.769, 615.162, 615.773, 617.051, 617.334, 619.156, 620.031,
#         621.343, 623.072, 625.256, 626.513, 632.269, 639.36 , 641.165,
#         641.995, 642.135, 643.085, 659.291, 659.387, 660.911, 675.015]),
#  array([513.3601, 515.0726, 515.1804, 515.903 , 516.2188, 519.4817,
#         519.8623, 523.2801, 524.2432, 525.0125, 528.1689, 530.222 ,
#         530.7276, 532.1997, 533.9835, 534.0885, 536.4799, 536.7395,
# ...

# %% [markdown]
# ## Fe II

# %%
wave_peak = np.array([4993.35,5132.66,5197.56,5284.10,5325.56,5414.05,5425.25,5534.83,6084.10,6432.68])
W_lon = np.array([26,12,66,43,24,15,26,40,11,29])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([499.335, 513.266, 519.756, 528.41 , 532.556, 541.405, 542.525,
#         553.483, 608.41 , 643.268]),
#  array([499.3324, 513.2648, 519.7494, 528.4057, 532.5536, 541.4035,
#         542.5224, 553.479 , 608.4089, 643.2651]),
#  array([499.3376, 513.2672, 519.7626, 528.4143, 532.5584, 541.4065,
#         542.5276, 553.487 , 608.4111, 643.2709]))

# %% [markdown]
# ## Na I

# %%
wave_peak = np.array([4664.81,4668.60,4982.81,5682.65,5688.22,6154.22,6160.75])
W_lon = np.array([28,29,54,77,97,23,40])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([466.481, 466.86 , 498.281, 568.265, 568.822, 615.422, 616.075]),
#  array([466.4782, 466.8571, 498.2756, 568.2573, 568.8123, 615.4197,
#         616.071 ]),
#  array([466.4838, 466.8629, 498.2864, 568.2727, 568.8317, 615.4243,
#         616.079 ]))

# %% [markdown]
# ## Mg I

# %%
wave_peak = np.array([4702.99,4730.04,5528.40,5711.10])
W_lon = np.array([146,35,157,78])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([470.299, 473.004, 552.84 , 571.11 ]),
#  array([470.2844, 473.0005, 552.8243, 571.1022]),
#  array([470.3136, 473.0075, 552.8557, 571.1178]))

# %% [markdown]
# ## Al I

# %%
wave_peak = np.array([6696.03,6698.67])
W_lon = np.array([18,17])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([669.603, 669.867]),
#  array([669.6012, 669.8653]),
#  array([669.6048, 669.8687]))

# %% [markdown]
# ## Si I

# %%
wave_peak = np.array([5793.08,6125.03,6131.58,6145.08])
W_lon = np.array([46,15,10,43])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([579.308, 612.503, 613.158, 614.508]),
#  array([579.3034, 612.5015, 613.157 , 614.5037]),
#  array([579.3126, 612.5045, 613.159 , 614.5123]))

# %% [markdown]
# ## Ca I

# %%
wave_peak = np.array([5581.80,5601.29,5857.46,6102.73,6122.23,6166.44,6169.04,6169.56,6439.08,6449.82,6455.60,6464.68,6471.66,6493.79,6499.65,6717.69])
W_lon = np.array([76,77,99,113,142,48,74,88,137,85,40,13,78,113,72,84,])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([558.18 , 560.129, 585.746, 610.273, 612.223, 616.644, 616.904,
#         616.956, 643.908, 644.982, 645.56 , 646.468, 647.166, 649.379,
#         649.965, 671.769]),
#  array([558.1724, 560.1213, 585.7361, 610.2617, 612.2088, 616.6392,
#         616.8966, 616.9472, 643.8943, 644.9735, 645.556 , 646.4667,
#         647.1582, 649.3677, 649.9578, 671.7606]),
#  array([558.1876, 560.1367, 585.7559, 610.2843, 612.2372, 616.6488,
#         616.9114, 616.9648, 643.9217, 644.9905, 645.564 , 646.4693,
#         647.1738, 649.3903, 649.9722, 671.7774]))

# %% [markdown]
# ## Ti I

# %%
wave_peak = np.array([4758.12,4759.28,4981.74,4997.10,5009.66,5016.17,5022.87,5039.96,5043.59,5087.06,5145.47,5147.48,5152.19,5210.39,5219.71,5295.78,5490.16,5866.46,5922.12,5978.55,6126.22,6258.11,6261.10,6554.24])
W_lon = np.array([29,32,115,48,35,75,79,94,16,22,29,52,51,108,34,14,18,51,22,20,22,47,41,18])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([475.812, 475.928, 498.174, 499.71 , 500.966, 501.617, 502.287,
#         503.996, 504.359, 508.706, 514.547, 514.748, 515.219, 521.039,
#         521.971, 529.578, 549.016, 586.646, 592.212, 597.855, 612.622,
#         625.811, 626.11 , 655.424]),
#  array([475.8091, 475.9248, 498.1625, 499.7052, 500.9625, 501.6095,
#         502.2791, 503.9866, 504.3574, 508.7038, 514.5441, 514.7428,
#         515.2139, 521.0282, 521.9676, 529.5766, 549.0142, 586.6409,
#         592.2098, 597.853 , 612.6198, 625.8063, 626.1059, 655.4222]),
#  array([475.8149, 475.9312, 498.1855, 499.7148, 500.9695, 501.6245,
#         502.2949, 504.0054, 504.3606, 508.7082, 514.5499, 514.7532,
#         515.2241, 521.0498, 521.9744, 529.5794, 549.0178, 586.6511,
#         592.2142, 597.857 , 612.6242, 625.8157, 626.1141, 655.4258]))

# %% [markdown]
# ## Cr I

# %%
wave_peak = np.array([4789.34,4829.37,4870.80,5296.70,5298.28,5345.81,5409.79,5783.87,5787.93,6330.10])
W_lon = np.array([44,21,29,76,87,97,109,10,11,14])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([478.934, 482.937, 487.08 , 529.67 , 529.828, 534.581, 540.979,
#         578.387, 578.793, 633.01 ]),
#  array([478.9296, 482.9349, 487.0771, 529.6624, 529.8193, 534.5713,
#         540.9681, 578.386 , 578.7919, 633.0086]),
#  array([478.9384, 482.9391, 487.0829, 529.6776, 529.8367, 534.5907,
#         540.9899, 578.388 , 578.7941, 633.0114]))

# %% [markdown]
# ## Ni I

# %%
wave_peak = np.array([4519.98,4604.99,4715.76,4756.52,4866.27,4953.21,4976.33,5003.75,5010.94,5017.58,5035.36,5084.10,5102.97,5115.40,5424.65,5435.86,5578.73,5587.87,5592.26,5709.56,5748.36,5846.99,5892.87,6007.31,6108.12,6128.98,6176.82,6177.25,6327.60,6482.80,6532.88,6586.33,6643.64,6767.77,6772.32])
W_lon = np.array([22,51,42,46,48,26,27,24,21,56,64,51,32,38,26,35,43,42,44,73,19,16,58,13,54,18,23,10,29,29,11,24,86,72,17])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([451.998, 460.499, 471.576, 475.652, 486.627, 495.321, 497.633,
#         500.375, 501.094, 501.758, 503.536, 508.41 , 510.297, 511.54 ,
#         542.465, 543.586, 557.873, 558.787, 559.226, 570.956, 574.836,
#         584.699, 589.287, 600.731, 610.812, 612.898, 617.682, 617.725,
#         632.76 , 648.28 , 653.288, 658.633, 664.364, 676.777, 677.232]),
#  array([451.9958, 460.4939, 471.5718, 475.6474, 486.6222, 495.3184,
#         497.6303, 500.3726, 501.0919, 501.7524, 503.5296, 508.4049,
#         510.2938, 511.5362, 542.4624, 543.5825, 557.8687, 558.7828,
#         559.2216, 570.9487, 574.8341, 584.6974, 589.2812, 600.7297,
#         610.8066, 612.8962, 617.6797, 617.724 , 632.7571, 648.2771,
#         653.2869, 658.6306, 664.3554, 676.7698, 677.2303]),
#  array([452.0002, 460.5041, 471.5802, 475.6566, 486.6318, 495.3236,
#         497.6357, 500.3774, 501.0961, 501.7636, 503.5424, 508.4151,
#         510.3002, 511.5438, 542.4676, 543.5895, 557.8773, 558.7912,
# ...

# %% [markdown]
# ## Sr I

# %%
wave_peak = np.array([4607.33])
W_lon = np.array([70])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([460.733]), array([460.726]), array([460.74]))

# %% [markdown]
# ## Y II

# %%
wave_peak = np.array([4883.68,5087.43,5123.21,5200.41,5205.72,5289.81,5402.78])
W_lon = np.array([105,94,71,82,101,24,38])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([488.368, 508.743, 512.321, 520.041, 520.572, 528.981, 540.278]),
#  array([488.3575, 508.7336, 512.3139, 520.0328, 520.5619, 528.9786,
#         540.2742]),
#  array([488.3785, 508.7524, 512.3281, 520.0492, 520.5821, 528.9834,
#         540.2818]))

# %% [markdown]
# ## Zr I

# %%
wave_peak = np.array([4772.30,4815.05,5385.13,6127.46,6134.57,6143.18])
W_lon = np.array([24,21,11,15,12,19])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([477.23 , 481.505, 538.513, 612.746, 613.457, 614.318]),
#  array([477.2276, 481.5029, 538.5119, 612.7445, 613.4558, 614.3161]),
#  array([477.2324, 481.5071, 538.5141, 612.7475, 613.4582, 614.3199]))

# %% [markdown]
# ## Zr II

# %%
wave_peak = np.array([4050.32,4442.99,5112.27,5350.35])
W_lon = np.array([79,69,47,31])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([405.032, 444.299, 511.227, 535.035]),
#  array([405.0241, 444.2921, 511.2223, 535.0319]),
#  array([405.0399, 444.3059, 511.2317, 535.0381]))

# %% [markdown]
# ## Mo I

# %%
wave_peak = np.array([5570.44])
W_lon = np.array([10])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([557.044]), array([557.043]), array([557.045]))

# %% [markdown]
# ## La II

# %%
#wave_peak = np.array([4086.71,5880.63,6774.33])
wave_peak = np.array([4086.77,4662.5,5114.5,5303.5])
W_lon = np.array([79,15,18,79])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([408.677, 466.25 , 511.45 , 530.35 ]),
#  array([408.6691, 466.2485, 511.4482, 530.3421]),
#  array([408.6849, 466.2515, 511.4518, 530.3579]))

# %% [markdown]
# ## Ce II

# %%
wave_peak = np.array([4418.79,4483.90,4486.91,4539.74,4562.37,4628.16,5187.45,5274.24,5330.58,5393.39])
W_lon = np.array([41,29,39,49,59,52,17,26,11,14])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([441.879, 448.39 , 448.691, 453.974, 456.237, 462.816, 518.745,
#         527.424, 533.058, 539.339]),
#  array([441.8749, 448.3871, 448.6871, 453.9691, 456.2311, 462.8108,
#         518.7433, 527.4214, 533.0569, 539.3376]),
#  array([441.8831, 448.3929, 448.6949, 453.9789, 456.2429, 462.8212,
#         518.7467, 527.4266, 533.0591, 539.3404]))

# %% [markdown]
# ## Nd II

# %%
wave_peak = np.array([4418.79,4483.90,4486.91,4539.74,4562.37,4628.16,5187.45,5274.24,5330.58,5393.39])
W_lon = np.array([41,29,39,49,59,52,17,26,11,14])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([441.879, 448.39 , 448.691, 453.974, 456.237, 462.816, 518.745,
#         527.424, 533.058, 539.339]),
#  array([441.8749, 448.3871, 448.6871, 453.9691, 456.2311, 462.8108,
#         518.7433, 527.4214, 533.0569, 539.3376]),
#  array([441.8831, 448.3929, 448.6949, 453.9789, 456.2429, 462.8212,
#         518.7467, 527.4266, 533.0591, 539.3404]))

# %% [markdown]
# ## Sm II

# %%
wave_peak = np.array([4318.94,4424.32,4467.34,4642.23,4676.90,4704.40])
W_lon = np.array([27,36,21,16,14,17])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([431.894, 442.432, 446.734, 464.223, 467.69 , 470.44 ]),
#  array([431.8913, 442.4284, 446.7319, 464.2214, 467.6886, 470.4383]),
#  array([431.8967, 442.4356, 446.7361, 464.2246, 467.6914, 470.4417]))

# %%
wave_peak = np.array([4662.5,5114.5,5303.5])
W_lon = np.array([27,27,27])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([466.25, 511.45, 530.35]),
#  array([466.2473, 511.4473, 530.3473]),
#  array([466.2527, 511.4527, 530.3527]))

# %% [markdown]
# ## Ba II

# %%
wave_peak = np.array([4554.0,4934.1,5853.7])
W_lon = np.array([27,36,21])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([455.4 , 493.41, 585.37]),
#  array([455.3973, 493.4064, 585.3679]),
#  array([455.4027, 493.4136, 585.3721]))

# %%
wave_peak = np.array([4057.81])
W_lon = np.array([28])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([405.781]), array([405.7782]), array([405.7838]))

# %% [markdown]
# ## O I

# %%
wave_peak = np.array([6296.079,  6296.487, 6296.585, 6296.646, 6296.853, 6296.939, 6297.452, 6297.646, 6297.793, 6297.889, 6298.073, 6298.411, 6298.495, 6298.530, 6298.533 , 6298.641, 6298.713, 6298.747, 6298.753, 6299.460, 6299.482  , 6299.519 , 6299.599, 6299.610, 6299.673, 6300.170, 6300.204, 6300.265, 6300.304  ,  6300.336  ,  6300.634  ,  6300.667  ,  6300.700  ,  6300.710  ,  6300.719  ,  6301.059  ,6301.182  ,6301.313  ,6301.444  ,6301.501  ,  6301.625  , 6301.768  ,6301.863  ,6302.104  ,6302.358  ,6302.402  ,6302.494  , 6302.846  ,6303.169  ,6303.354  ,6303.423  ,6303.460  ,6303.756  ,6304.262  ,6304.341  ,6304.345  ,6304.821  ,6304.906  ,6305.002  ,6305.135  ,6305.144  ,6305.264, 6305.296  ,6305.447  ,6305.657  ,6306.019  ,6306.342  ,6306.497  ,6307.000 ])
W_lon = np.array([57.1, 23.0 , 22.0 , 22.0 , 22.0 , 27.0 , 26.0 , 21.0 , 26.0 , 14.0 , 22.0 , 60.1 , 24.0 , 23.1,  92.0, 23.0 , 23.0 , 28.0 , 24.1 , 22.0 , 58.1 ,72.0 ,14.0,24.0,40.0  , 25.0 ,58.0 ,07.0121, 8.0, 28.0, 21.1, 21.1, 21.1,25.0 , 21.1,24.0 ,62.1 ,23.0 ,22.0 ,26.0 ,  14.0 , 42.0 ,26.0 ,23.0 ,59.1 ,62.1 ,26.0 , 22.0 ,62.1 ,22.0 ,63.1 ,26.0 ,22.0 ,23.0 ,40.0 ,40.0 ,26.0 ,25.0 ,14.0 ,64.1 ,62.1 ,59.1 ,26.1 ,57.1 ,21.0 ,21.0 ,25.0 ,23.0 ,26.0])/1000
wave_base = wave_peak - W_lon
wave_top = wave_peak + W_lon

wave_peak/10, wave_base/10, wave_top/10
# Out:
# (array([629.6079, 629.6487, 629.6585, 629.6646, 629.6853, 629.6939,
#         629.7452, 629.7646, 629.7793, 629.7889, 629.8073, 629.8411,
#         629.8495, 629.853 , 629.8533, 629.8641, 629.8713, 629.8747,
#         629.8753, 629.946 , 629.9482, 629.9519, 629.9599, 629.961 ,
#         629.9673, 630.017 , 630.0204, 630.0265, 630.0304, 630.0336,
#         630.0634, 630.0667, 630.07  , 630.071 , 630.0719, 630.1059,
#         630.1182, 630.1313, 630.1444, 630.1501, 630.1625, 630.1768,
#         630.1863, 630.2104, 630.2358, 630.2402, 630.2494, 630.2846,
#         630.3169, 630.3354, 630.3423, 630.346 , 630.3756, 630.4262,
#         630.4341, 630.4345, 630.4821, 630.4906, 630.5002, 630.5135,
#         630.5144, 630.5264, 630.5296, 630.5447, 630.5657, 630.6019,
#         630.6342, 630.6497, 630.7   ]),
#  array([629.60219   , 629.6464    , 629.6563    , 629.6624    ,
#         629.6831    , 629.6912    , 629.7426    , 629.7625    ,
# ...

# %%
# Definir una función que aplica estilos a columnas específicas con colores diferentes
def resaltar_columnas(s, colores):
    return ['background-color: {}'.format(colores.get(col, '')) for col in s.index]

# %% [markdown]
# ## Parámetros Atmoféricos

# %%
Parametros = pd.DataFrame()
T_eff = [4765.30,4700,4850,4858,4935,4800,4750]         # Temperatura efectiva K
log_g = [2.24,1.9,2.05,2.05,2.33,2.8,2.5]               # Gravedad superficial (dex) 
Fe_H = [-1.57,-1.55,-1.49,-1.48,-1.44,-1.55,'Nan']      # Metalicidad
ξ = [1.40,1.5,1.5,'Nan','Nan',2.7,1.5]                  # Microturbulencia [km/s]
Ref = ['1. Este Trabajo (2024)','2. Pereira (2019)','3. Karinkuzhi & Goswami (2015)','4. Koleva & Vazdekis (2012)','5. Vauglin & Koleva (2011)','6. Luck & Bond (1991)','7. Sneden (1983)']                           

Parametros['$T_{eff}~ [K]$'] = T_eff 
Parametros['$log(g)~ [dex]$'] = log_g 
Parametros['$Fe/H ~[dex]$'] = Fe_H
Parametros["$ξ ~[km/s]$"] = ξ
Parametros['$Ref.$'] = Ref

Parametros
# Out:
#    $T_{eff}~ [K]$  $log(g)~ [dex]$ $Fe/H ~[dex]$ $ξ ~[km/s]$  \
# 0          4765.3             2.24         -1.57         1.4
# 1          4700.0             1.90         -1.55         1.5
# 2          4850.0             2.05         -1.49         1.5
# 3          4858.0             2.05         -1.48         Nan
# 4          4935.0             2.33         -1.44         Nan
# 5          4800.0             2.80         -1.55         2.7
# 6          4750.0             2.50           Nan         1.5
#
#                            $Ref.$
# 0          1. Este Trabajo (2024)
# 1               2. Pereira (2019)
# 2  3. Karinkuzhi & Goswami (2015)
# 3     4. Koleva & Vazdekis (2012)
# 4      5. Vauglin & Koleva (2011)
# 5           6. Luck & Bond (1991)
# 6                7. Sneden (1983)

# %%
Abundancias = pd.DataFrame()
Elemento = ['Fe I','Fe II','Na I','Mg I','Al I','Si I','Ca I','Ti I','Cr I','Ni I','Sr I','Y II','Zr I','Zr II','Mo I']
A_X = [5.90,5.74,5.50,6.50,5.49,6.74,5.38,3.67,4.01,4.62,4.94,1.36,2.34,4.58,2.93]
Err_A_X = [0.45,1.44,1.63,1.52,6.69,2.23,1.00,0.74,1.14,0.87,3.90,1.64,2.73,7.56,1363.02]
# Synthesis
Num_Line_sy = [70,10,7,4,2,4,16,24,10,35,1,7,6,3,1]
X_H_sy = [-1.59,-1.76,-0.82,-1.07,-0.97,-0.81,-0.97,-1.35,-1.66,-1.62,1.97,-0.88,-0.26,1.98,1.01] 
Err_X_H_sy = [0.45,1.44,1.63,1.52,6.69,2.23,1.00,0.74,1.14,0.87,3.90,1.64,2.73,7.56,1363.02] 
X_Fe_sy = [-0.04,-0.21,0.73,0.48,0.58,0.74,0.58,0.20,-0.11,-0.07,3.52,0.67,1.29,3.53,2.56]
Err_X_Fe_sy = [0.45,1.44,1.63,1.52,6.69,2.23,1.00,0.74,1.14,0.87,3.90,1.64,2.73,7.56,1363.02]
chisq = [1.43,0.14,0.47,0.68,0.00,0.02,0.47,0.71,0.22,0.0021,0.43,0.23,0.13,0.29,0.01]
# Equivalent widths
Num_Line_eqw = ['Nan',44,7,12,1,54,47,143,91,118,2,21,10,9,4]
X_H_eqw = ['Nan',-0.76,-0.77,-0.86,-0.87,-0.30,-0.86,-0.59,-0.40,-0.89,0.14,-0.65,0.17,0.09,0.07]
desv_X_H_eqw = ['Nan',0.96,0.43,0.51,0,0.64,0.49,0.80,1.02,0.81,1.02,0.74,0.55,0.51,0.43]
X_Fe_eqw = ['Nan',0.79,0.78,0.62,0.68,1.25,0.69,0.96,0.95,0.66,1.69,0.90,1.72,1.64,1.62]
desv_X_Fe_eqw = ['Nan',0.96,0.43,0.51,0,0.64,0.49,0.80,1.02,0.81,1.02,0.74,0.55,0.51,0.43]

# Datos del artículo
Num_Line_art = [70,10,8,5,6,6,16,24,10,35,1,7,6,4,1]
logϵ_o = [7.50,7.50,6.33,7.58,6.47,7.55,6.36,5.02,5.67,6.25,2.97,2.24,2.60,2.60,1.92]
logϵ = [5.95,5.92,5.59,6.73,5.66,6.66,5.39,3.72,4.06,4.70,2.04,1.53,2.20,2.28,1.47]
X_H_art = [-1.55,-1.58,-0.74,-0.85,-0.81,-0.89,-0.97,-1.30,-1.61,-1.55,-0.93,-0.71,-0.40,-0.32,-0.45]
X_Fe_art = [0.001,0.001,0.81,0.70,0.74,0.66,0.58,0.25,-0.06,0.00,0.62,0.84,1.15,1.23,1.10]

#Errores porcentuales
#Err_X_H_Sy = np.abs((np.array(X_H_sy)-np.array(X_H_art))/np.array(X_H_art))*100
#Err_X_Fe_Sy = np.abs((np.array(X_Fe_sy)-np.array(X_Fe_art))/np.array(X_Fe_art))*100

#Err_X_H_eqw = np.abs((np.array(X_H_eqw)-np.array(X_H_art))/np.array(X_H_art))*100
#Err_X_Fe_eqw = np.abs((np.array(X_Fe_eqw)-np.array(X_H_art))/np.array(X_H_art))*100

Abundancias['Elementos'] =  Elemento
Abundancias['N° Lineas Sy'] = Num_Line_sy
Abundancias['A(X)'] = A_X
#Abundancias['Error Absoluto'] = Err_A_X
Abundancias['[X/H] Sy'] = X_H_sy
Abundancias['[X/Fe] Sy'] = X_Fe_sy
Abundancias['Chi-Square Sy'] = chisq
Abundancias['N° Lineas Eqw'] = Num_Line_eqw
Abundancias['[X/H] Eqw'] = X_H_eqw
Abundancias['[X/Fe] Eqw'] = X_Fe_eqw
Abundancias['N° Lineas Art'] = Num_Line_art
Abundancias['A(X)$_\odot$ Art'] = logϵ_o
Abundancias['A(X) Art'] = logϵ
Abundancias['[X/H] Art'] = X_H_art
Abundancias['[X/Fe] Art'] = X_Fe_art

# Abundancias['Err [X/H] Sy'] = Err_X_H_Sy
# Abundancias['Err [X/Fe] Sy'] = Err_X_Fe_Sy
# Abundancias['Err [X/H] eqw'] = Err_X_H_eqw
# Abundancias['Err [X/Fe] eqw'] = Err_X_Fe_eqw

# Especificar los colores para cada columna
colores_resaltar = {'N° Lineas Sy': '#89B0AE','A(X)': '#89B0AE','[X/H] Sy': '#89B0AE','[X/Fe] Sy': '#89B0AE',  'N° Lineas Eqw': '#BEE3DB','[X/H] Eqw':'#BEE3DB','[X/Fe] Eqw':'#BEE3DB','N° Lineas Art':'#FFD6BA','A(X)$_\odot$ Art':'#FFD6BA','A(X) Art':'#FFD6BA','[X/H] Art':'#FFD6BA','[X/Fe] Art':'#FFD6BA'}

# Aplicar estilos al DataFrame
estilos = Abundancias.style.apply(lambda x: resaltar_columnas(x, colores_resaltar), axis=1)

# Mostrar el DataFrame con los estilos aplicados
estilos
# Out:
# <style type="text/css">
# #T_4fa48_row0_col0, #T_4fa48_row0_col5, #T_4fa48_row1_col0, #T_4fa48_row1_col5, #T_4fa48_row2_col0, #T_4fa48_row2_col5, #T_4fa48_row3_col0, #T_4fa48_row3_col5, #T_4fa48_row4_col0, #T_4fa48_row4_col5, #T_4fa48_row5_col0, #T_4fa48_row5_col5, #T_4fa48_row6_col0, #T_4fa48_row6_col5, #T_4fa48_row7_col0, #T_4fa48_row7_col5, #T_4fa48_row8_col0, #T_4fa48_row8_col5, #T_4fa48_row9_col0, #T_4fa48_row9_col5, #T_4fa48_row10_col0, #T_4fa48_row10_col5, #T_4fa48_row11_col0, #T_4fa48_row11_col5, #T_4fa48_row12_col0, #T_4fa48_row12_col5, #T_4fa48_row13_col0, #T_4fa48_row13_col5, #T_4fa48_row14_col0, #T_4fa48_row14_col5 {
#   background-color: ;
# }
# ...

# %% [markdown]
# * El color Azúl oscuro: Es el cálculo de las abundancias por medio de sintesis
# * El color Azúl claro: Es el cálculo de las abundancias por medio del ancho equivalente
# * El color Salmón: Son los valores de las abundancias encontradas en el Artículo de Pereira

# %%
Abundancias_F = pd.DataFrame()
Elemento = ['Fe I','Fe II','Na I','Mg I','Al I','Si I','Ca I','Ti I','Cr I','Ni I','Sr I','Y II','Zr I','Zr II','Mo I','La II','Ce II','Nd II', 'Sm II']
Num_Lineas = [70,10,7,4,2,4,16,24,10,35,1,7,6,3,1,2,10,21,5]
A_X = [5.99,5.89,5.45,6.59,5.56,6.78,5.42,3.79,4.11,4.73,2.42,1.52,2.25,2.17,1.60,0.69,0.77,0.44,0.06 ]
Err_Abs = [0.45,1.45,1.21,1.13,3.81,2.27,0.96,0.76,1.14,0.65,3.50,1.59,2.18,2.24,6.47,3.55,1.18,0.90,1.46]
X_H = [-1.50,-1.61,-0.87,-0.99,-0.90,-0.76,-0.94,-1.23,-1.56,-1.52,-0.55,-0.72,-0.35,-0.43,-0.31,-0.47,-0.81,-1.05,-0.94]
X_Fe = [0.07,-0.04,0.70,0.58,0.67,0.81,0.63,0.34,0.01,0.05,1.02,0.85,1.22,1.14,1.26,1.10,0.76,0.52,0.63]
chisq = [1.41,0.14,0.22,0.17,0.00,0.02,0.46,0.67,0.20,0.60,0.02,0.22,0.09,0.20,0.00,0.02,0.36,0.63,0.21]

# Datos del artículo
Num_Line_art = [70,10,8,5,6,6,16,24,10,35,1,7,6,4,1,'syn',10,21,6]
#logϵ_o = [7.50,7.50,6.33,7.58,6.47,7.55,6.36,5.02,5.67,6.25,2.97,2.24,2.60,2.60,1.92]
logϵ = [5.95,5.92,5.59,6.73,5.66,6.66,5.39,3.72,4.06,4.70,2.04,1.53,2.20,2.28,1.47,-0.07,0.54,0.34,-0.35]
X_H_art = [-1.55,-1.58,-0.74,-0.85,-0.81,-0.89,-0.97,-1.30,-1.61,-1.55,-0.93,-0.71,-0.40,-0.32,-0.45,-1.24,-1.04,-1.16,-1.36]
X_Fe_art = [0.01,0.01,0.81,0.70,0.74,0.66,0.58,0.25,-0.06,0.01,0.62,0.84,1.15,1.23,1.10,0.31,0.51,0.39,0.19]

Err_A = np.abs(np.array(A_X)-np.array(logϵ))/np.array(logϵ)
Err_H = np.abs(np.array(X_H)-np.array(X_H_art))/np.array(X_H_art)
Err_Fe = np.abs(np.array(X_Fe)-np.array(X_Fe_art))/np.array(X_Fe_art)

Abundancias_F['$Elemento$'] = Elemento
Abundancias_F['$N° Líneas$'] = Num_Lineas
Abundancias_F['$A(X)$'] = A_X
Abundancias_F['$Err_{Abs}$'] = Err_Abs
Abundancias_F['$[X/H]$'] = X_H
Abundancias_F['$[X/Fe]$'] = X_Fe
Abundancias_F['$chisq$'] = chisq

Abundancias_F['$N° Lineas Art$'] = Num_Line_art
#Abundancias_F['A(X)$_\odot$ Art'] = logϵ_o
Abundancias_F['$A(X) Art$'] = logϵ
Abundancias_F['$[X/H] Art$'] = X_H_art
Abundancias_F['$[X/Fe] Art$'] = X_Fe_art

Abundancias_F['$Err~ Rel~ A(X)$'] = np.abs(Err_A)*100
Abundancias_F['$Err~ Rel~ X/H$'] = np.abs(Err_H)*100
Abundancias_F['$Err~ Rel~ X/Fe$'] = np.abs(Err_Fe)*100


# Especificar los colores para cada columna
colores_resaltar = {'$N° Líneas$': '#89B0AE','$A(X)$': '#89B0AE','$[X/H]$': '#89B0AE','$[X/Fe]$': '#89B0AE',  '$N° Lineas Art$':'#FFD6BA','$A(X) Art$':'#FFD6BA','$[X/H] Art$':'#FFD6BA','$[X/Fe] Art$':'#FFD6BA'}

# Aplicar estilos al DataFrame
estilos = Abundancias_F.style.apply(lambda x: resaltar_columnas(x, colores_resaltar), axis=1)

# Mostrar el DataFrame con los estilos aplicados
estilos
# Out:
# <style type="text/css">
# ...

# %%
Abundancias_F = pd.DataFrame()
Elemento = ['O','Fe I','Fe II','Na I','Mg I','Al I','Si I','Ca I','Ti I','Cr I','Ni I','Sr I','Y II','Zr I','Zr II','Mo I','Ba II','La II','Ce II','Nd II', 'Sm II']
Num_Lineas = [4,70,10,4,4,2, 4, 14, 22, 10 , 32, 1, 7, 5, 2, 1,3, 3,9, 19,5]
A_X = [7.11,5.98, 5.83, 5.49, 6.66, 5.56, 6.74, 5.47, 3.72, 4.10, 4.72, 2.48, 1.47, 2.22, 2.29, 1.57,1.26, 0.31, 0.65, 0.32,-0.22]
#Err_Abs = [0.45,1.45,1.21,1.13,3.81,2.27,0.96,0.76,1.14,0.65,3.50,1.59,2.18,2.24,6.47,3.55,1.18,0.90,1.46]
X_H = [-1.71,-1.51, -1.67, -0.84, -0.92, -0.90, -0.80, -0.88, -1.30, -1.57, -1.53, -0.49, -0.76, -0.37, -0.31, -0.35, -0.87,-0.85, -1.05, -1.13,-1.22]
X_Fe = [-0.17,0.03, -0.13, 0.70, 0.62, 0.64, 0.74,  0.66, 0.24, -0.03, 0.01, 1.05, 0.78, 1.17, 1.23, 1.19,0.67, 0.69, 0.49, 0.41,0.32]
#chisq = [1.41,0.14,0.22,0.17,0.00,0.02,0.46,0.67,0.20,0.60,0.02,0.22,0.09,0.20,0.00,0.02,0.36,0.63,0.21]

# Datos del artículo
Num_Line_art = ['syn',70,10,8,5,6,6,16,24,10,35,1,7,6,4,1,3,'syn',10,21,6]
#logϵ_o = [7.50,7.50,6.33,7.58,6.47,7.55,6.36,5.02,5.67,6.25,2.97,2.24,2.60,2.60,1.92]
logϵ = [7.43,5.95,5.92,5.59,6.73,5.66,6.66,5.39,3.72,4.06,4.70,2.04,1.53,2.20,2.28,1.47,1.20,-0.07,0.54,0.34,-0.35]
X_H_art = [-1.40,-1.55,-1.58,-0.74,-0.85,-0.81,-0.89,-0.97,-1.30,-1.61,-1.55,-0.93,-0.71,-0.40,-0.32,-0.45,-0.93,-1.24,-1.04,-1.16,-1.36]
X_Fe_art = [0.15,0.01,0.01,0.81,0.70,0.74,0.66,0.58,0.25,-0.06,0.01,0.62,0.84,1.15,1.23,1.10,0.62,0.31,0.51,0.39,0.19]

Err_A = np.abs(np.array(A_X)-np.array(logϵ))/np.array(logϵ)
Err_H = np.abs(np.array(X_H)-np.array(X_H_art))/np.array(X_H_art)
Err_Fe = np.abs(np.array(X_Fe)-np.array(X_Fe_art))/np.array(X_Fe_art)

Abundancias_F['$Elemento$'] = Elemento
Abundancias_F['$N° Líneas$'] = Num_Lineas
Abundancias_F['$A(X)$'] = A_X
#Abundancias_F['$Err_{Abs}$'] = Err_Abs
Abundancias_F['$[X/H]$'] = X_H
Abundancias_F['$[X/Fe]$'] = X_Fe
#Abundancias_F['$chisq$'] = chisq

Abundancias_F['$N° Lineas Art$'] = Num_Line_art
#Abundancias_F['A(X)$_\odot$ Art'] = logϵ_o
Abundancias_F['$A(X) Art$'] = logϵ
Abundancias_F['$[X/H] Art$'] = X_H_art
Abundancias_F['$[X/Fe] Art$'] = X_Fe_art

Abundancias_F['$Err~ Rel\%~ A(X)$'] = np.abs(Err_A)*100
Abundancias_F['$Err~ Rel\%~ X/H$'] = np.abs(Err_H)*100
Abundancias_F['$Err~ Rel\%~ X/Fe$'] = np.abs(Err_Fe)*100


# Especificar los colores para cada columna
colores_resaltar = {'$N° Líneas$': '#89B0AE','$A(X)$': '#89B0AE','$[X/H]$': '#89B0AE','$[X/Fe]$': '#89B0AE',  '$N° Lineas Art$':'#FFD6BA','$A(X) Art$':'#FFD6BA','$[X/H] Art$':'#FFD6BA','$[X/Fe] Art$':'#FFD6BA'}

# Aplicar estilos al DataFrame
estilos = Abundancias_F.style.apply(lambda x: resaltar_columnas(x, colores_resaltar), axis=1)

# Mostrar el DataFrame con los estilos aplicados
estilos
# Out:
# <style type="text/css">
# ...

# %%
x = np.arange(0,len(Elemento))
plt.plot(Elemento, X_Fe, '*', markersize = 7,  mfc="w", mec="#952271", label = 'HD 55496')
plt.ylim(-1,2)
plt.ylabel('[X/Fe]' ,fontsize = 12)
plt.title("Abundancias químicas de HD55496",fontsize = 14)
plt.xticks(x, Elemento, rotation=90)
plt.grid(linestyle='-', linewidth=0.1)
plt.legend()

# %%
# Elementos que quieres buscar
elementos_ls = ['Sr I', 'Y II', 'Zr I', 'Zr II', 'Mo I']

# Filtrar el DataFrame para obtener solo las filas correspondientes a ls
filtrado_ls= Abundancias_F.loc[Abundancias_F['$Elemento$'].isin(elementos_ls)]
Abundancias_ls = filtrado_ls.set_index('$Elemento$').loc[elementos_ls, '$[X/Fe]$'].values
ls_Fe = np.mean(Abundancias_ls)
print(Abundancias_ls)
print("[ls/Fe] = ",ls_Fe)

# Elementos que quieres buscar
elementos_hs = ['Ba II', 'La II', 'Ce II', 'Nd II']

# Filtrar el DataFrame para obtener solo las filas correspondientes a hs
filtrado_hs= Abundancias_F.loc[Abundancias_F['$Elemento$'].isin(elementos_hs)]
Abundancias_hs = filtrado_hs.set_index('$Elemento$').loc[elementos_hs, '$[X/Fe]$'].values
hs_Fe = np.mean(Abundancias_hs)
print(Abundancias_hs)
print("[hs/Fe] = ",hs_Fe)

hs_ls = -hs_Fe/ls_Fe
print("[hs/ls] = ",hs_ls)
# Out:
# [1.05 0.78 1.17 1.23 1.19]
# [ls/Fe] =  1.084
# [0.67 0.69 0.49 0.41]
# [hs/Fe] =  0.565
# [hs/ls] =  -0.5212177121771217

# %%
Err_ls = np.abs(ls_Fe-0.96)/0.96 * 100
Err_hs = np.abs(hs_Fe-0.46)/0.46 * 100
Err_hs_ls = np.abs(hs_ls-(0.50))/0.50 * 100

print(f"Err_ls = {np.around(Err_ls,1)} %, Err_hs = {np.around(Err_hs,1)} %, Err_hs/ls = {np.around(Err_hs_ls,1)} %")
# Out:
# Err_ls = 12.9 %, Err_hs = 22.8 %, Err_hs/ls = 204.2 %

# %% [markdown]
# ## Estrellas de Bario:
#
# Estas estrellas fueron obtenidas de Castro et al (2016): Tabla3 y Tabla8
# * https://ui.adsabs.harvard.edu/abs/2016yCat..74594299D/abstract
# * https://cdsarc.cds.unistra.fr/viz-bin/cat/J/MNRAS/459/4299#/browse

# %%
# Lee el archivo .dat y carga los datos en un DataFrame
# Asegúrate de reemplazar 'archivo.dat' con el nombre de tu archivo .dat
# Si el archivo .dat tiene un delimitador diferente a la coma (','), especifícalo con el parámetro 'sep'
# Por ejemplo, si el delimitador es una tabulación ('\t'), puedes usar sep='\t'
df1 = pd.read_csv('table3.dat', sep='\s+',header=None, names=['Star', 'Teff', 'logg', '[FeI/H]','e_[FeI/H]','o_[FeI/H]', '[FeII/H]','e_[FeII/H]','o_[FeII/H]', 'vt', 'Source'])
df2 = pd.read_csv('table8.dat', sep='\s+',header=None, names=['Star', '[Y/Fe]', '[Zr/Fe]', '[La/Fe]', '[Ce/Fe]', '[Nd/Fe]', '[s/Fe]', '[hs/ls]', 'Ref'])

# Muestra las primeras filas del DataFrame para verificar que se haya cargado correctamente
df1.head()
# Out:
#         Star  Teff  logg  [FeI/H]  e_[FeI/H]  o_[FeI/H]  [FeII/H]  e_[FeII/H]  \
# 0  BD-083194  4900   3.0    -0.10       0.16         36     -0.05        0.21
# 1  BD-094337  4800   2.6    -0.24       0.21         28     -0.27        0.21
# 2  BD-142678  5200   3.1     0.01       0.12         43      0.01        0.11
# 3  CD-272233  4700   2.4    -0.25       0.18         51     -0.24        0.17
# 4  CD-298822  5100   2.8     0.04       0.15         61      0.03        0.07
#
#    o_[FeII/H]   vt Source
# 0          13  1.6      I
# 1           7  2.7      I
# 2          11  1.4      I
# 3          11  1.4      I
# 4          10  1.3      I

# %%
df2.head()
# Out:
#         Star  [Y/Fe]  [Zr/Fe]  [La/Fe]  [Ce/Fe]  [Nd/Fe]  [s/Fe]  [hs/ls] Ref
# 0  BD-083194    0.95     0.95     1.94     1.27     1.35    1.29     0.57   I
# 1  BD-094337    1.11     1.51     0.00     1.44     1.56    1.41     0.19   I
# 2  BD-142678    1.02     0.85     1.08     0.87     0.87    0.94     0.01   I
# 3  CD-272233    0.89     0.73     1.41     0.94     0.96    0.99     0.29   I
# 4  CD-298822    1.06     0.81     1.49     1.06     0.91    1.07     0.22   I

# %%
Barium_Stars = pd.DataFrame()
Barium_Stars['Star'] = df1['Star']
Barium_Stars['[FeI/H]'] = df1['[FeI/H]']
Barium_Stars['[FeII/H]'] = df1['[FeII/H]']
Barium_Stars['[hs/ls]'] = df2['[hs/ls]']
Barium_Stars
# Out:
#           Star  [FeI/H]  [FeII/H]  [hs/ls]
# 0    BD-083194    -0.10     -0.05     0.57
# 1    BD-094337    -0.24     -0.27     0.19
# 2    BD-142678     0.01      0.01     0.01
# 3    CD-272233    -0.25     -0.24     0.29
# 4    CD-298822     0.04      0.03     0.22
# ..         ...      ...       ...      ...
# 177    HD88927     0.02      0.04    -0.16
# 178   HD211221    -0.11     -0.17     0.28
# 179  BD+092384    -0.98     -0.99     0.31
# 180    HD89638    -0.19     -0.18     0.22
# 181   HD187762    -0.30     -0.30     0.31
#
# [182 rows x 4 columns]

# %% [markdown]
# ## Estrellas binary CEMP-s
# 1. Preston & Sneden (2001) https://ui.adsabs.harvard.edu/abs/2001AJ....122.1545P/abstract

# %%
Binary_CEMPs1 = pd.DataFrame()
Binary_CEMPs1['Star'] = ['CS 22880-074', 'CS 22881-036', 'CS 22898-027', 'CS 22942-019']
# [hs/ls] = [<Ba, La>/<Y, Zr>]
Binary_CEMPs1['[Fe/H]'] = [-1.76, -2.06, -2.15, -2.67]
Binary_CEMPs1['[ls/Fe]'] = [np.mean([0.6,0.73]), np.mean([1.01,0.95]), np.mean([0.95,1.39]), 0]
Binary_CEMPs1['[hs/Fe]'] = [np.mean([1.34,1.24]), np.mean([1.93,1.59]), np.mean([2.27,2.28]), np.mean([1.50,1.85])]
Binary_CEMPs1['[hs/ls]'] = Binary_CEMPs1['[hs/Fe]']/Binary_CEMPs1['[ls/Fe]']
Binary_CEMPs1
# Out:
#            Star  [Fe/H]  [ls/Fe]  [hs/Fe]   [hs/ls]
# 0  CS 22880-074   -1.76    0.665    1.290  1.939850
# 1  CS 22881-036   -2.06    0.980    1.760  1.795918
# 2  CS 22898-027   -2.15    1.170    2.275  1.944444
# 3  CS 22942-019   -2.67    0.000    1.675       inf

# %% [markdown]
# 2. Sivarani et al. (2004) https://ui.adsabs.harvard.edu/abs/2004A%26A...413.1073S/abstract
# 3. Barbuy et al. (2005) https://ui.adsabs.harvard.edu/abs/2005A%26A...429.1031B/abstract
# 4.  Lucatello et al. (2003) https://ui.adsabs.harvard.edu/search/q=doi%3A%2210.1086%2F345886%22&sort=date%20desc%2C%20bibcode%20desc&p_=0

# %%
Binary_CEMPs2 = pd.DataFrame()
Binary_CEMPs2['Star'] = ['CS 29497-030','CS 22948-27', 'CS 29497-34', 'HE 0024-2523', 'CS 22964-161']
# [hs/ls] = [<Ba, La>/<Y, Zr>]
Binary_CEMPs2['[Fe/H]'] = [-2.71, -2.47, -2.90, -2.72, -2.5]
#CH_star['[ls/Fe]'] = [np.mean([0.6,0.73]), np.mean([1.01,0.95]), np.mean([0.95,1.39]), 0]
#CH_star['[hs/Fe]'] = [np.mean([1.34,1.24]), np.mean([1.93,1.59]), np.mean([2.27,2.28]), np.mean([1.50,1.85])]
Binary_CEMPs2['[hs/ls]'] = [1.02, 0.97, 1.28, (np.mean([1.46,1.8])/np.mean([1.22,0.91])), (np.mean([1.26,1.07,1.29,1.01])/np.mean([0.52,0.29,0.69]))]
Binary_CEMPs2
# Out:
#            Star  [Fe/H]   [hs/ls]
# 0  CS 29497-030   -2.71  1.020000
# 1   CS 22948-27   -2.47  0.970000
# 2   CS 29497-34   -2.90  1.280000
# 3  HE 0024-2523   -2.72  1.530516
# 4  CS 22964-161   -2.50  2.315000

# %% [markdown]
# ## Estrellas CH
# 1. Drisya Karinkuzhi & Aruna Goswami (2014) https://academic.oup.com/mnras/article/446/3/2348/2891844#78647889

# %%
CH_star= pd.DataFrame()
CH_star['Star'] = ['HD 89668', 'HD 92545', 'HD 104979', 'HD 107574', 'HD 111721', 'HD 122202', 'HD 126681', 'HD 148897', 'HD 164922', 'HD 167768', 'HD 204613']
CH_star['[Fe/H]'] = [-0.13, -0.21, -0.26, -0.48, -1.11, -0.63, -0.90, -1.02, 0.22, -0.51, -0.24]
CH_star['[hs/ls]'] = [0.35,0.92,0.18,-0.15,0.93,-0.28,0.78,0.14,-0.37,-0.37,-0.11]
CH_star
# Out:
#          Star  [Fe/H]  [hs/ls]
# 0    HD 89668   -0.13     0.35
# 1    HD 92545   -0.21     0.92
# 2   HD 104979   -0.26     0.18
# 3   HD 107574   -0.48    -0.15
# 4   HD 111721   -1.11     0.93
# 5   HD 122202   -0.63    -0.28
# 6   HD 126681   -0.90     0.78
# 7   HD 148897   -1.02     0.14
# 8   HD 164922    0.22    -0.37
# 9   HD 167768   -0.51    -0.37
# 10  HD 204613   -0.24    -0.11

# %%
Fe_H_HD55496 = Abundancias_F.loc[Abundancias_F['$Elemento$'] == 'Fe I', '$[X/H]$'].values[0]

plt.figure(figsize=(8,7))
plt.plot(np.array(Barium_Stars['[FeI/H]']),np.array(Barium_Stars['[hs/ls]']) , 'x', color ='#781C6D', markersize = 5, label = 'Gigantes de Bario')
plt.plot(np.array(Binary_CEMPs1['[Fe/H]']),np.array(Binary_CEMPs1['[hs/ls]']) , 's', color ='#3498DB', markersize = 5, label = 'Binarias CEMPs1')
plt.plot(np.array(Binary_CEMPs2['[Fe/H]']),np.array(Binary_CEMPs2['[hs/ls]']) , 's', color ='#EC7063', markersize = 5, label = 'Binarias CEMPs2')
plt.plot(-1.55,0.62 , 'o', color ='#52BE80', markersize = 5, label = 'TYC 5619-106-1')
plt.plot(np.array(CH_star['[Fe/H]']),np.array(CH_star['[hs/ls]']) , 'v', color ='#E87DD0', markersize = 5, label = 'Estrellas CH')

plt.plot(Fe_H_HD55496 ,hs_ls , '*', markersize = 7,  mfc="w", mec="#FB9B06", label = 'HD 55496')

plt.ylim(-1.0, 2.5)
plt.xlim(-4.0,0.5)
plt.xlabel('[FeI/H]',fontsize = 12)
plt.ylabel('[hs/ls]' ,fontsize = 12)
plt.title("Comparación con estrellas reportadas",fontsize = 14)
plt.grid(linestyle='-', linewidth=0.1)
plt.legend()

# %%
Fe_H_HD55496 = Abundancias_F.loc[Abundancias_F['$Elemento$'] == 'Fe I', '$[X/H]$'].values[0]

plt.figure(figsize=(8,7))
plt.plot(np.array(Barium_Stars['[FeII/H]']),np.array(Barium_Stars['[hs/ls]'] ), 'x', color ='#781C6D', markersize = 5, label = 'Gigantes de Bario')
plt.plot(Fe_H_HD55496 ,hs_ls , '*', markersize = 7,  mfc="w", mec="#FB9B06", label = 'HD 55496')

plt.ylim(-1.0, 2)
plt.xlim(-4.0,0.5)
plt.xlabel('[FeII/H]',fontsize = 12)
plt.ylabel('[hs/ls]' ,fontsize = 12)
plt.title("Comparación con estrellas reportadas",fontsize = 14)
plt.grid(linestyle='-', linewidth=0.1)
plt.legend()

# %% [markdown]
# ## Comparación de HD 55496 con estrellas de cúmulos globulares [Na/Fe] vs [O/Fe]
# 1. Carretta et al. (2006) https://ui.adsabs.harvard.edu/abs/2006A%26A...450..523C/abstract

# %%
Star = ['07183', '07315', '07536', '07558', '08204', '08679', '08826', '09724', '10012', '10105', '10265', '10341', '13575', '30523', '30720', '30873', '30900', '31361', '31823', '31851', '32398', '32469', '32909', '32924', '33452', '33918', '34634', '35265', '37496', '37505', '37831', '37998', '38228', '38244', '38559', '38967', '39060', '40983', '41008', '41050', '41207', '41688','41828', '41969', '42122', '42996', '43097', '43247', '43794', '44526' , '44665', '44984', '44996', '45443', '45496', '45701', '46036', '46520', '46587', '46663', '46868', '46908', '46924', '47421', '47502', '47805', '48001', '48011', '48424', '49122', '49493', '49753', '50685', '50910', '51256', '51519', '51918', '51930', '52006', '52048', '52647', '52891', '53209', '53284', '53629', '54264', '54284', '54644', '54756', '55354', '55609', '55822', '56710', '56924']
O_Fe = [+0.109, +0.384, +0.386, +0.428, +0.324, -0.136, -0.605, -0.171, -0.235, +0.366, -0.193, -0.876, +0.284, +0.400, +0.334, -0.145, +0.346, -0.544, -0.362, -0.610, +0.184, +0.140, -0.192, +0.286, +0.389, +0.314, +0.333, +0.381, +0.350, +0.218, +0.448, +0.386, +0.452, +0.461, -0.279, +0.230, +0.274, -0.541, -0.414, +0.264, +0.292, -0.233, +0.115 , +0.293 , +0.263 , -0.151 , -0.399 , -0.568 , +0.430 , -0.460 , +0.174 , +0.395 , +0.202 , +0.303 , -0.390 , +0.222 , +0.375 , -0.532 , -0.770 , -0.782 , +0.218 , +0.253 , +0.040 , +0.009 , -0.821 , +0.184 , +0.145 , -0.829 , +0.265 , +0.311 , +0.438 , +0.156 , +0.402 , -0.126 , +0.042 , +0.517 , -0.692 , -0.006 , -0.943 , +0.312, +0.219 , +0.016 , -0.374 , +0.468 , +0.388 , +0.149 , +0.171 , +0.223 , +0.005 , -0.346 , +0.237 , -0.517 , +0.375 , +0.246 ]
Na_Fe =[+0.217, -0.132, +0.004, +0.041, -0.010, +0.303, +0.470, +0.426, +0.369, -0.118, +0.409, +0.531, -0.043, -0.026, -0.028, +0.485, +0.109, +0.580, +0.426, +0.573, -0.034, +0.363, +0.312, +0.469, -0.037, +0.071, -0.068, -0.063, +0.023, +0.064, +0.085, +0.168, +0.016, +0.069, +0.691, +0.090, +0.148, +0.380, +0.696, +0.034, +0.083, +0.425, +0.166, -0.029, +0.172, +0.523, +0.440, +0.378, -0.111, +1.014, +0.285, +0.014, +0.131, -0.046, +0.300, +0.058, -0.132, +0.800, +0.690, +0.476, +0.182, +0.270, +0.327, +0.392, +0.628, +0.387, +0.316, +0.650, +0.131, +0.189, +0.115, +0.230, -0.134, +0.397, +0.372, +0.031, +0.590, +0.407, +0.635, +0.114, -0.009, +0.177, +0.391, -0.087, -0.019, +0.167, +0.242, -0.143, +0.297, +0.434, +0.046, +0.773, +0.062, +0.263]

Stars_GC= pd.DataFrame()
Stars_GC['Star'] = Star
Stars_GC['[O/Fe]'] = O_Fe
Stars_GC['[Na/Fe]'] = Na_Fe
Stars_GC.head()

Star_ω = [ 'ROA 102', 'ROA 209', 'ROA 213', 'ROA 219', 'ROA 236', 'ROA 238', 'ROA 245', 'ROA 253', 'ROA 324', 'ROA 383']

# %%
plt.figure(figsize=(8,5))
plt.plot(np.array(Stars_GC['[O/Fe]']),np.array(Stars_GC['[Na/Fe]']) , 'x', color ='#298AE5', markersize = 5, label = 'NGC 2808')
plt.plot(-0.47,0.43, 'o', color ='#52BE80', markersize = 5, label = 'TYC 5619-106-1')

plt.plot(-0.17, 0.7, '*', markersize = 7,  mfc="w", mec="#FB9B06", label = 'HD 55496')

plt.ylim(-0.5, 1)
plt.xlim(-1.0,1.0)
plt.xlabel('[O/Fe]',fontsize = 12)
plt.ylabel('[Na/Fe]' ,fontsize = 12)
plt.title("Comparación con estrellas de Cúmulos Globulares",fontsize = 14)
plt.grid(linestyle='-', linewidth=0.1)
plt.legend()

# %% [markdown]
# ### Gráficos de Violín

# %% [markdown]
# Elementos de procesos s

# %% [markdown]
# #### Referencias: https://academic.oup.com/mnras/article/446/3/2348/2891844#78647889
#
# ##### 1.Our work 2. Luck & Bond (1991) 3. Smith et al. (1993) 4. Allen & Barbuy (2006a) 5. Luck (1991) 6. Gratton & Sneden (1994) 7. Fulbright (2000) 8. Luck & Heiter (2007).
#
# |Estrella|Referencia|
# | --- | --- |
# |HD204613 | Ref 1 |
# |HD92545  | Ref 4 |
# |HD104979 | Ref 1 |
# |HD107574 | Ref 4 |
# |HD111721 | Ref 6 |
# |HD148897 | Ref 1 |
# |HD167768 | Ref 1 |

# %%
# Elementos que quieres buscar
elementos_ls = ['Sr I', 'Y II', 'Zr I', 'Zr II', 'Mo I']


# Filtrar el DataFrame para obtener solo las filas correspondientes a ls
filtrado_ls= Abundancias_F.loc[Abundancias_F['$Elemento$'].isin(elementos_ls)]
Abundancias_ls = filtrado_ls.set_index('$Elemento$').loc[elementos_ls, '$[X/Fe]$'].values
Z_mean = np.mean(Abundancias_ls[-3:-1])
Abundancias_ls = list(Abundancias_ls)
Abundancias_ls.pop(3)
Abundancias_ls[2] = Z_mean
Abundancias_ls

cmap = plt.get_cmap('plasma') #gnuplot
colors = [cmap(i) for i in np.linspace(0, 1, 9)]


ls_HD204613	 = [1.71, 0.97, 1.14]
ls_HD92545	= [0.67, 0.64, 0.75]
ls_HD104979 = [0.99,0.71,0.85]
ls_HD107574 = [0.67,0.64,0.75]
ls_HD111721	= [-0.13,0.14,-0.45]
ls_HD148897 = [0.31,0.03,-0.47]
ls_HD167768 = [0.77,0.56,0.2]

Promedio_ls = [np.mean([ls_HD204613[0],ls_HD92545[0],ls_HD104979[0],ls_HD107574[0],ls_HD111721[0],ls_HD148897[0],ls_HD167768[0]]),np.mean([ls_HD204613[1],ls_HD92545[1],ls_HD104979[1],ls_HD107574[1],ls_HD111721[1],ls_HD148897[1],ls_HD167768[1]]),np.mean([ls_HD204613[2],ls_HD92545[2],ls_HD104979[2],ls_HD107574[2],ls_HD111721[2],ls_HD148897[2],ls_HD167768[2]])]

elementos_ls = ['Sr', 'Y', 'Zr', 'Mo']
x = np.array([0,1.5,3])
x1 = np.array([0,1.5+0.4,3+0.7])
x2 = np.array([0+0.1,1.5+0.1,3+0.1])
x3 = np.array([0+0.2,1.5+0.2,3+0.2])
x4 = np.array([0+0.3,1.5+0.3,3+0.3])
x5 = np.array([0+0.4,1.5+0.4,3+0.4])
x6 = np.array([0+0.5,1.5+0.5,3+0.5])
x7 = np.array([0+0.6,1.5+0.6,3+0.6])
x8 = np.array([0+0.7,1.5+0.7,3+0.7])

plt.figure(figsize=(8,5))

plt.axvspan(-0.1, 0.8, alpha=0.05, color='blue')
plt.axvspan(1.4, 2.3, alpha=0.05, color='blue')
plt.axvspan(2.9, 3.8, alpha=0.05, color='blue')

plt.plot(x, Abundancias_ls[:3], '*', markersize = 7, color=colors[0], label = 'HD 55496')
plt.plot(x2, ls_HD204613, 'v', markersize = 6, color =colors[1], label = 'HD 204613')
plt.plot(x3, ls_HD92545, 'v', markersize = 6, color =colors[2], label = 'HD 92545')
plt.plot(x4, ls_HD104979, 'v', markersize = 6, color =colors[3], label = 'HD 104979')
plt.plot(x5, ls_HD107574, 'v', markersize = 6, color =colors[4], label = 'HD 107574')
plt.plot(x6, ls_HD111721, 'v', markersize = 6, color =colors[5], label = 'HD 111721')
plt.plot(x7, ls_HD148897, 'v', markersize = 6, color =colors[6], label = 'HD 148897')
plt.plot(x8, ls_HD167768, 'v', markersize = 6, color =colors[7], label = 'HD 167768')
plt.plot(x1, Promedio_ls, '.--', linewidth = 1, markersize = 7, color ="r")


plt.ylim(-1,2)
plt.xlim(-1,len(elementos_ls[:3])+1.8)
plt.xticks(x4, elementos_ls[:3], rotation=0)
plt.ylabel('[X/Fe]' ,fontsize = 12)
plt.title("Abundancias de elementos ligeros de procesos s",fontsize = 14)
plt.grid(linestyle='-', linewidth=0.1)
plt.legend(bbox_to_anchor=(0.8, 0.5, 0.5, 0.5))

# %%
# Elementos que quieres buscar

elementos_hs = ['Ba II', 'La II', 'Ce II', 'Nd II', 'Sm II']

# Filtrar el DataFrame para obtener solo las filas correspondientes a hs
filtrado_hs= Abundancias_F.loc[Abundancias_F['$Elemento$'].isin(elementos_hs)]
Abundancias_hs = filtrado_hs.set_index('$Elemento$').loc[elementos_hs, '$[X/Fe]$'].values


hs_HD204613	= [1.04, 1.21, 1.24, 1.02,1.61]
hs_HD92545	= [1.04,0.72,0.60,0.42,0.24]
hs_HD104979 = [0.94,1.11,1.06,1.13,1.17]
hs_HD107574 = [1.04,0.72,0.6,0.42,0.24]
hs_HD111721 = [0.08,0.04,0.03,0.17,0.22]
hs_HD148897 = [-0.65,0.29,-0.16,0.13,0.58]
hs_HD167768 = [-0.36,-0.54,0.06,0.65,0.9]
Promedio_hs = [np.mean([hs_HD204613[0],hs_HD92545[0],hs_HD104979[0],hs_HD107574[0],hs_HD111721[0],hs_HD148897[0],hs_HD167768[0]]),np.mean([hs_HD204613[1],hs_HD92545[1],hs_HD104979[1],hs_HD107574[1],hs_HD111721[1],hs_HD148897[1],hs_HD167768[1]]),np.mean([hs_HD204613[2],hs_HD92545[2],hs_HD104979[2],hs_HD107574[2],hs_HD111721[2],hs_HD148897[2],hs_HD167768[2]]),np.mean([hs_HD204613[3],hs_HD92545[3],hs_HD104979[3],hs_HD107574[3],hs_HD111721[3],hs_HD148897[3],hs_HD167768[3]]),np.mean([hs_HD204613[4],hs_HD92545[4],hs_HD104979[4],hs_HD107574[4],hs_HD111721[4],hs_HD148897[4],hs_HD167768[4]])]

elementos_hs = ['Ba', 'La', 'Ce', 'Nd', 'Sm']
x = np.array([0,1.5,3, 4.5, 6])
x1 = np.array([0,1.5+0.4,3+0.7, 4.5 +0.8, 6+0.8])
x2 = np.array([0+0.1,1.5+0.1,3+0.1, 4.5+0.1, 6+0.1])
x3 = np.array([0+0.2,1.5+0.2,3+0.2, 4.5+0.2, 6+0.2])
x4 = np.array([0+0.3,1.5+0.3,3+0.3, 4.5+0.3, 6+0.3])
x5 = np.array([0+0.4,1.5+0.4,3+0.4, 4.5+0.4, 6+0.4])
x6 = np.array([0+0.5,1.5+0.5,3+0.5, 4.5+0.5, 6+0.5])
x7 = np.array([0+0.6,1.5+0.6,3+0.6, 4.5+0.6, 6+0.6])
x8 = np.array([0+0.7,1.5+0.7,3+0.7, 4.5+0.7, 6+0.7])

plt.figure(figsize=(8,5))

plt.axvspan(-0.1, 0.8, alpha=0.05, color='blue')
plt.axvspan(1.4, 2.3, alpha=0.05, color='blue')
plt.axvspan(2.9, 3.8, alpha=0.05, color='blue')
plt.axvspan(4.4, 5.3, alpha=0.05, color='blue')
plt.axvspan(5.9, 6.8, alpha=0.05, color='blue')

plt.plot(x, Abundancias_hs, '*', markersize = 7, color=colors[0], label = 'HD 55496')
plt.plot(x2, hs_HD204613, 'v', markersize = 6, color =colors[1], label = 'HD 204613')
plt.plot(x3, hs_HD92545, 'v', markersize = 6, color =colors[2], label = 'HD 92545')
plt.plot(x4, hs_HD104979, 'v', markersize = 6, color =colors[3], label = 'HD 104979')
plt.plot(x5, hs_HD107574, 'v', markersize = 6, color =colors[4], label = 'HD 107574')
plt.plot(x6, hs_HD111721, 'v', markersize = 6, color =colors[5], label = 'HD 111721')
plt.plot(x7, hs_HD148897, 'v', markersize = 6, color =colors[6], label = 'HD 148897')
plt.plot(x8, hs_HD167768, 'v', markersize = 6, color =colors[7], label = 'HD 167768')
plt.plot(x1, Promedio_hs, '.--', linewidth = 1, markersize = 7, color ="r")

plt.ylim(-1,2)
#plt.xlim(-1,len(elementos_hs))
plt.xticks(x5, elementos_hs, rotation=0)
plt.ylabel('[X/Fe]' ,fontsize = 12)
plt.title("Abundancias de elementos pesados de procesos s",fontsize = 14)
plt.grid(linestyle='-', linewidth=0.1)
plt.legend(bbox_to_anchor=(0.8, 0.5, 0.5, 0.5))

# %%
Stars_Fe_H = [-1.5,-0.24,-0.21,-0.26,-0.48,-1.11,-1.02,-0.51]
Stars_Sr = [Abundancias_ls[0],ls_HD204613[0], ls_HD92545[0], ls_HD104979[0], ls_HD107574[0], ls_HD111721[0], ls_HD148897[0], ls_HD167768[0]]
Stars_Y = [Abundancias_ls[1],ls_HD204613[1], ls_HD92545[1], ls_HD104979[1], ls_HD107574[1], ls_HD111721[1], ls_HD148897[1], ls_HD167768[1]]
Stars_Zr = [Abundancias_ls[2],ls_HD204613[2], ls_HD92545[2], ls_HD104979[2], ls_HD107574[2], ls_HD111721[2], ls_HD148897[2], ls_HD167768[2]]
Stars_Ba = [Abundancias_hs[0],hs_HD204613[0], hs_HD92545[0], hs_HD104979[0], hs_HD107574[0], hs_HD111721[0], hs_HD148897[0], hs_HD167768[0]]
Stars_La = [Abundancias_hs[1],hs_HD204613[1], hs_HD92545[1], hs_HD104979[1], hs_HD107574[1], hs_HD111721[1], hs_HD148897[1], hs_HD167768[1]]
Stars_Ce = [Abundancias_hs[2],hs_HD204613[2], hs_HD92545[2], hs_HD104979[2], hs_HD107574[2], hs_HD111721[2], hs_HD148897[2], hs_HD167768[2]]
Stars_Nd = [Abundancias_hs[3],hs_HD204613[3], hs_HD92545[3], hs_HD104979[3], hs_HD107574[3], hs_HD111721[3], hs_HD148897[3], hs_HD167768[3]]
Stars_Sm = [Abundancias_hs[4],hs_HD204613[4], hs_HD92545[4], hs_HD104979[4], hs_HD107574[4], hs_HD111721[4], hs_HD148897[4], hs_HD167768[4]]

fig = plt.figure(figsize=(8,8))

gs = fig.add_gridspec(3, 3, hspace=0, wspace=0)
(ax1,ax2,ax3), (ax4,ax5,ax6), (ax7,ax8,ax9) = gs.subplots(sharex='col', sharey='row')
ax2.set_title('Abundancias [Fe/H] vs [X/Fe]')
ax1.plot(Stars_Fe_H[0], Stars_Sr[0], '*', markersize = 6, color =colors[0])
ax2.plot(Stars_Fe_H[0], Stars_Y[0], '*', markersize = 6, color =colors[0])
ax3.plot(Stars_Fe_H[0], Stars_Zr[0], '*', markersize = 6, color =colors[0], label = 'HD 55496')
ax4.plot(Stars_Fe_H[0], Stars_Ba[0], '*', markersize = 6, color =colors[0])
ax5.plot(Stars_Fe_H[0], Stars_La[0], '*', markersize = 6, color =colors[0])
ax6.plot(Stars_Fe_H[0], Stars_Ce[0], '*', markersize = 6, color =colors[0])
ax7.plot(Stars_Fe_H[0], Stars_Nd[0], '*', markersize = 6, color =colors[0])
ax8.plot(Stars_Fe_H[0], Stars_Sm[0], '*', markersize = 6, color =colors[0])

ax1.plot(Stars_Fe_H[1:], Stars_Sr[1:], 'v', markersize = 6, color =colors[5])
ax2.plot(Stars_Fe_H[1:], Stars_Y[1:], 'v', markersize = 6, color =colors[5])
ax3.plot(Stars_Fe_H[1:], Stars_Zr[1:], 'v', markersize = 6, color =colors[5], label = 'Estrellas CH')
ax4.plot(Stars_Fe_H[1:], Stars_Ba[1:], 'v', markersize = 6, color =colors[5])
ax5.plot(Stars_Fe_H[1:], Stars_La[1:], 'v', markersize = 6, color =colors[5])
ax6.plot(Stars_Fe_H[1:], Stars_Ce[1:], 'v', markersize = 6, color =colors[5])
ax7.plot(Stars_Fe_H[1:], Stars_Nd[1:], 'v', markersize = 6, color =colors[5])
ax8.plot(Stars_Fe_H[1:], Stars_Sm[1:], 'v', markersize = 6, color =colors[5])

ax1.text(-1.8, 2, 'Sr',fontsize = 14)
ax2.text(-1.8, 2, 'Y',fontsize = 14)
ax3.text(-1.8, 2, 'Zr',fontsize = 14)
ax4.text(-1.8, 2, 'Ba',fontsize = 14)
ax5.text(-1.8, 2, 'La',fontsize = 14)
ax6.text(-1.8, 2, 'Ce',fontsize = 14)
ax7.text(-1.8, 2, 'Nd',fontsize = 14)
ax8.text(-1.8, 2, 'Sm',fontsize = 14)


ax4.set_ylabel('[X/Fe]' ,fontsize = 12)
ax8.set_xlabel('[Fe/H]' ,fontsize = 12)
ax3.legend()
for ax in fig.get_axes():
    ax.label_outer()
    ax.set_xlim(-1.96,0)
    ax.set_ylim(-0.96,2.4)
    ax.grid(linestyle='-', linewidth=0.1)

# %% [markdown]
# ## Estrellas de Bario

# %%
Fe_H_Barium = []
for i in range(len(df1['[FeI/H]'])):
    Fe_H_Barium.append(np.mean([df1['[FeI/H]'][i],df1['[FeII/H]'][i]]))
df1['[Fe/H]'] = Fe_H_Barium
df1
# Out:
#           Star  Teff  logg  [FeI/H]  e_[FeI/H]  o_[FeI/H]  [FeII/H]  \
# 0    BD-083194  4900   3.0    -0.10       0.16         36     -0.05
# 1    BD-094337  4800   2.6    -0.24       0.21         28     -0.27
# 2    BD-142678  5200   3.1     0.01       0.12         43      0.01
# 3    CD-272233  4700   2.4    -0.25       0.18         51     -0.24
# 4    CD-298822  5100   2.8     0.04       0.15         61      0.03
# ..         ...   ...   ...      ...        ...        ...       ...
# 177    HD88927  4600   2.3     0.02       0.13         50      0.04
# 178   HD211221  4800   2.3    -0.11       0.09         55     -0.17
# 179  BD+092384  4900   2.5    -0.98       0.10         88     -0.99
# 180    HD89638  4900   2.4    -0.19       0.11         69     -0.18
# 181   HD187762  4800   2.4    -0.30       0.11         56     -0.30
#
#      e_[FeII/H]  o_[FeII/H]   vt Source  [Fe/H]
# 0          0.21          13  1.6      I  -0.075
# 1          0.21           7  2.7      I  -0.255
# ...

# %%
fig = plt.figure(figsize=(9,6))

gs = fig.add_gridspec(2, 3, hspace=0, wspace=0)
(ax1,ax2,ax3), (ax4,ax5,ax6) = gs.subplots(sharex='col', sharey='row')
ax2.set_title('Abundancias [Fe/H] vs [X/Fe]')

ax1.plot(Stars_Fe_H[0], Stars_Y[0], '*', markersize = 6, color =colors[0])
ax2.plot(Stars_Fe_H[0], Stars_Zr[0], '*', markersize = 6, color =colors[0])
ax3.plot(Stars_Fe_H[0], Stars_La[0], '*', markersize = 6, color =colors[0], label = 'HD 55496')
ax4.plot(Stars_Fe_H[0], Stars_Ce[0], '*', markersize = 6, color =colors[0])
ax5.plot(Stars_Fe_H[0], Stars_Nd[0], '*', markersize = 6, color =colors[0])

ax1.plot(np.array(df1['[Fe/H]']), np.array(df2['[Y/Fe]']), '^', mfc="w", markersize = 6, color =colors[6])
ax2.plot(np.array(df1['[Fe/H]']), np.array(df2['[Zr/Fe]']), '^',  mfc="w",markersize = 6, color =colors[6])
ax3.plot(np.array(df1['[Fe/H]']), np.array(df2['[La/Fe]']), '^', mfc="w", markersize = 6, color =colors[6], label = 'Gigantes de Bario')
ax4.plot(np.array(df1['[Fe/H]']), np.array(df2['[Ce/Fe]']), '^',  mfc="w",markersize = 6, color =colors[6])
ax5.plot(np.array(df1['[Fe/H]']), np.array(df2['[Nd/Fe]']), '^', mfc="w",markersize = 6, color =colors[6])



ax1.text(-1.8, 2.5, 'Y',fontsize = 14)
ax2.text(-1.8, 2.5, 'Zr',fontsize = 14)
ax3.text(-1.8, 2.5, 'La',fontsize = 14)
ax4.text(-1.8, 2.5, 'Ce',fontsize = 14)
ax5.text(-1.8, 2.5, 'Nd',fontsize = 14)

ax1.set_ylabel('[X/Fe]' ,fontsize = 12)
ax4.set_ylabel('[X/Fe]' ,fontsize = 12)
ax5.set_xlabel('[Fe/H]' ,fontsize = 12)
ax3.legend(bbox_to_anchor=(1.3, 0.5, 0.5, 0.5))
for ax in fig.get_axes():
    ax.label_outer()
    ax.set_xlim(-1.96,0.5)
    ax.set_ylim(-0.96,3)
    ax.grid(linestyle='-', linewidth=0.1)

# %%
fig = plt.figure(figsize=(15,3))

gs = fig.add_gridspec(1, 5, hspace=0, wspace=0)
(ax1,ax2,ax3,ax4,ax5) = gs.subplots(sharex='col', sharey='row')
ax3.set_title('Abundancias [Fe/H] vs [X/Fe]')

ax1.plot(Stars_Fe_H[0], Stars_Y[0], '*', markersize = 6, color =colors[0], label = 'HD 55496')
ax2.plot(Stars_Fe_H[0], Stars_Zr[0], '*', markersize = 6, color =colors[0])
ax3.plot(Stars_Fe_H[0], Stars_La[0], '*', markersize = 6, color =colors[0])
ax4.plot(Stars_Fe_H[0], Stars_Ce[0], '*', markersize = 6, color =colors[0])
ax5.plot(Stars_Fe_H[0], Stars_Nd[0], '*', markersize = 6, color =colors[0])

ax1.plot(np.array(df1['[Fe/H]']), np.array(df2['[Y/Fe]']), '^', mfc="w", markersize = 6, color =colors[6], label = 'Gigantes de Bario')
ax2.plot(np.array(df1['[Fe/H]']), np.array(df2['[Zr/Fe]']), '^',  mfc="w",markersize = 6, color =colors[6])
ax3.plot(np.array(df1['[Fe/H]']), np.array(df2['[La/Fe]']), '^', mfc="w", markersize = 6, color =colors[6])
ax4.plot(np.array(df1['[Fe/H]']), np.array(df2['[Ce/Fe]']), '^',  mfc="w",markersize = 6, color =colors[6])
ax5.plot(np.array(df1['[Fe/H]']), np.array(df2['[Nd/Fe]']), '^', mfc="w",markersize = 6, color =colors[6])



ax1.text(-1.8, 2.5, 'Y',fontsize = 14)
ax2.text(-1.8, 2.5, 'Zr',fontsize = 14)
ax3.text(-1.8, 2.5, 'La',fontsize = 14)
ax4.text(-1.8, 2.5, 'Ce',fontsize = 14)
ax5.text(-1.8, 2.5, 'Nd',fontsize = 14)

ax1.set_ylabel('[X/Fe]' ,fontsize = 12)
ax4.set_ylabel('[X/Fe]' ,fontsize = 12)
#ax5.legend(bbox_to_anchor=(1.3, 0.5, 0.5, 0.5))
ax1.legend()

for ax in fig.get_axes():
    ax.label_outer()
    ax.set_xlim(-1.96,0.5)
    ax.set_ylim(-0.96,3)
    ax.set_xlabel('[Fe/H]' ,fontsize = 12)
    ax.grid(linestyle='-', linewidth=0.1)
